# %%
from barf.biased_rf import BiasedRFClassifier, RandomForestClassifier
from barf.base import train_test_split, classifier_report, k_fold_validation, roc_curve
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = pd.read_csv('data/diabetes.csv')

# %% [markdown]
# ## data inspection

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
label, count = np.unique(data['Outcome'], return_counts=True)
print(dict(zip(label, count)))
# Out:
# {0: 500, 1: 268}

# %%
sns.pairplot(data)

# %% [markdown]
# The inspection show no null values, however, there are values that doesn't make physical/medical sense. Most of those abnormal values represents a small subset of the overall data.
#
# - `Glucose` == 0
# - `BloodPressure` == 0
# - `SkinThickness` == 0: here we have a significant amount of rows with 0 skin thickness mesaurements
# - `BMI` == 0
#
# Below we replace those 0 values with nulls to flag them in the dataset.

# %%
for col in ['Glucose', 'BloodPressure', 'SkinThickness', 'BMI']:
    data.loc[:, col] = data[col].replace({0: np.nan})

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  763.000000     733.000000     541.000000  768.000000
# mean      3.845052  121.686763      72.405184      29.153420   79.799479
# std       3.369578   30.535641      12.382158      10.476982  115.244002
# min       0.000000   44.000000      24.000000       7.000000    0.000000
# 25%       1.000000   99.000000      64.000000      22.000000    0.000000
# 50%       3.000000  117.000000      72.000000      29.000000   30.500000
# 75%       6.000000  141.000000      80.000000      36.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  757.000000                768.000000  768.000000  768.000000
# mean    32.457464                  0.471876   33.240885    0.348958
# std      6.924988                  0.331329   11.760232    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.243750   24.000000    0.000000
# 50%     32.300000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)

# %% [markdown]
# ### Skin Thickness
#
# The new pairplot shows that whereever thee is `SkinThickness` entry they seem to corrleate to other features, especially `BMI` closely. This observation suggests that information contained in `SkinThickness` could be already in other features. Therefore, we first try to build a model without `SkinThickness` and try to impute it later with other features to build another model with the imputed `SkinThickness`. We can also use an ensemble approach where we build a model with skin thickness after dropping nulls and a model without skin thickness then use both models to make predictions depending on if skin thickness is available.
#
# ### BMI, Glucose, and Blood Pressure
#
# There are not too many missing values from those features so we first build a model without the row containing any null values.

# %%
data_nosk = data.drop(columns=['SkinThickness'])
data_nosk = data_nosk.dropna(how='any')
data_nosk.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure     Insulin         BMI  \
# count   724.000000  724.000000     724.000000  724.000000  724.000000
# mean      3.866022  121.882597      72.400552   84.494475   32.467127
# std       3.362803   30.750030      12.379870  117.016513    6.888941
# min       0.000000   44.000000      24.000000    0.000000   18.200000
# 25%       1.000000   99.750000      64.000000    0.000000   27.500000
# 50%       3.000000  117.000000      72.000000   48.000000   32.400000
# 75%       6.000000  142.000000      80.000000  130.500000   36.600000
# max      17.000000  199.000000     122.000000  846.000000   67.100000
#
#        DiabetesPedigreeFunction         Age     Outcome
# count                724.000000  724.000000  724.000000
# mean                   0.474765   33.350829    0.343923
# std                    0.332315   11.765393    0.475344
# min                    0.078000   21.000000    0.000000
# 25%                    0.245000   24.000000    0.000000
# 50%                    0.379000   29.000000    0.000000
# 75%                    0.627500   41.000000    1.000000
# max                    2.420000   81.000000    1.000000

# %%
train, test = train_test_split(data_nosk, random_seed=42)
train.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure     Insulin         BMI  \
# count   507.000000  507.000000     507.000000  507.000000  507.000000
# mean      3.826430  121.934911      72.331361   84.114398   32.207692
# std       3.306696   30.447222      12.175620  120.722048    6.937334
# min       0.000000   44.000000      30.000000    0.000000   18.200000
# 25%       1.000000  100.000000      64.000000    0.000000   27.300000
# 50%       3.000000  117.000000      72.000000   44.000000   32.000000
# 75%       6.000000  140.000000      80.000000  130.000000   36.500000
# max      13.000000  199.000000     114.000000  846.000000   67.100000
#
#        DiabetesPedigreeFunction         Age     Outcome
# count                507.000000  507.000000  507.000000
# mean                   0.454586   33.333333    0.329389
# std                    0.303217   12.141676    0.470455
# min                    0.078000   21.000000    0.000000
# 25%                    0.244000   24.000000    0.000000
# 50%                    0.370000   29.000000    0.000000
# 75%                    0.599000   41.000000    1.000000
# max                    2.329000   81.000000    1.000000

# %%
test.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure     Insulin         BMI  \
# count   217.000000  217.000000     217.000000  217.000000  217.000000
# mean      3.958525  121.760369      72.562212   85.382488   33.073272
# std       3.496444   31.517157      12.871770  108.126881    6.751497
# min       0.000000   57.000000      24.000000    0.000000   19.500000
# 25%       1.000000   97.000000      64.000000    0.000000   27.800000
# 50%       3.000000  117.000000      74.000000   61.000000   32.900000
# 75%       6.000000  144.000000      80.000000  135.000000   37.000000
# max      17.000000  197.000000     122.000000  579.000000   59.400000
#
#        DiabetesPedigreeFunction         Age     Outcome
# count                217.000000  217.000000  217.000000
# mean                   0.521912   33.391705    0.377880
# std                    0.388685   10.862291    0.485979
# min                    0.084000   21.000000    0.000000
# 25%                    0.251000   25.000000    0.000000
# 50%                    0.402000   30.000000    0.000000
# 75%                    0.686000   41.000000    1.000000
# max                    2.420000   68.000000    1.000000

# %% [markdown]
# ## Modeling
#
# The label `1` has less members than label `0` but the ratio between the number of members in those two labels are not significantly away from 1 so we will build two models using Random Forest and Biased Random Forest respectively and compare the performance.

# %% [markdown]
# ### biased rf

# %%
brf = BiasedRFClassifier()

results = k_fold_validation(brf, trainx, trainy, folds=10, callbacks=[roc_curve, classifier_report])
# Out:
# /mnt/c/Users/theya/develop/ML_Technical/barf/base.py:110: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   self.name = 'BaseEstimator'

# %%
results.keys()
# Out:
# dict_keys(['fold_1', 'fold_2', 'fold_3', 'fold_4', 'fold_5', 'fold_6', 'fold_7', 'fold_8', 'fold_9', 'fold_10'])

# %%
results['fold_1']
# Out:
# [(array([ 0,  2, 36]), array([ 0,  9, 15]), array([1., 0.])),
#  {'true_positives': 165.0,
#   'true_negatives': 1440.0,
#   'false_positives': 396.0,
#   'false_negatives': 600.0}]
